# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv('data/2020/players.csv')

# %%
with open('players_columns.json', 'w') as file:
    json.dump(list(df[df['match_id'] == 5178214128].columns), file)

# %%
df[df['match_id'] == 5178214128].to_csv('players_example.csv')
