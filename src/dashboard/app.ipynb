# %%
import pandas as pd
import numpy as np

import os
import sys
sys.path.append(os.path.abspath('./src/dashboard'))
sys.path.append(os.path.abspath('./src'))

from db_functions import DotaDB
db = DotaDB('kaggle')
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# Cell In[6], line 11
#       9 from db_functions import DotaDB
#      10 db = DotaDB('kaggle')
# ---> 11 db.query_select('SELECT * FROM match_details;')
#
# File ~\Projects\Dota\src\db_functions.py:39, in DotaDB.query_select(self, query, identifiers, params)
#      36 else:
#      37     final_query = sql.SQL(query)
# ---> 39 cur.execute(final_query, params)
#      40 return cur.fetchall() if cur.description else None
#
# File ~\Projects\Dota\.venv\Lib\site-packages\psycopg\cursor.py:117, in Cursor.execute(self, query, params, prepare, binary)
#     113         self._conn.wait(
#     114             self._execute_gen(query, params, prepare=prepare, binary=binary)
#     115         )
#     116 except e._NO_TRACEBACK as ex:
# --> 117     raise ex.with_traceback(None)
#     118 return self
#
# UndefinedTable: relation "match_details" does not exist
# LINE 1: SELECT * FROM match_details;
#                       ^
