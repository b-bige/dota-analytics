# %%
import pandas as pd
import numpy as np
import os
import sys
import httpx

sys.path.append(os.path.abspath('./src'))
import db_functions as dbf

db = dbf.DotaDB()

# %%
query = '''
    query($teamIds: [Int]!) {
        teams(teamIds: $teamIds) {
            name
            tag
            dateCreated
            isPro
            isLocked
            countryCode
            countryName
            url
            logo
            baseLogo
            bannerLogo
            leagues {
                id
            }
        }
    }
'''
with httpx.Client() as client:
    db.query_stratz(client, query, variables={'teamIds': [1, 2]})
# Out:
# WARNING:root:Retry attempt 1 after error: Client error '403 Forbidden' for url 'https://api.stratz.com/graphql'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
# Failed to interrupt the Kernel.
#
# request to http://localhost:8888/api/kernels/eec32c85-39c0-40e0-a42f-1ac4c2ccf65a/restart?1772734996533 failed, reason:.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
